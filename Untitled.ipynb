# %%
#Dependencies and file import/read
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

mouse_data = pd.read_csv('/Users/kscomputer/Desktop/Matplotlib-Challenge/Resources/Mouse_metadata.csv')
study_data = pd.read_csv('/Users/kscomputer/Desktop/Matplotlib-Challenge/Resources/Study_results.csv')

# %%
mouse_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
study_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
#merge into one dataset on mouseID and how 'outer'
merged = pd.merge(mouse_data,study_data, on='Mouse ID', how='outer')
merged
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
#check # of mice with unique on Mouse ID done to make sure all mouse data carried over
count = merged['Mouse ID'].value_counts()
count
# Out:
# g989    13
# g570    10
# i557    10
# i738    10
# c758    10
#         ..
# n482     1
# u153     1
# b447     1
# f932     1
# h428     1
# Name: Mouse ID, Length: 249, dtype: int64

# %% [raw]
# merged.duplicated()

# %%
#next get rid of duplicate data
mouse_drop = merged.drop_duplicates()
mouse_drop
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1892 rows x 8 columns]

# %%
#check count of mouse_drop to make sure all mice are present
count_drop = mouse_drop['Mouse ID'].value_counts()
count_drop
# Out:
# g989    12
# g570    10
# i557    10
# i738    10
# c758    10
#         ..
# n482     1
# u153     1
# b447     1
# f932     1
# h428     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation 
# and SEM of the tumor volume for each regimen
ram_groupby = mouse_drop.groupby('Drug Regimen')

# %%
#with ram_groupby series loc column tumor volume to get mean  of tumor volume for each regimen
drug_mean = ram_groupby['Tumor Volume (mm3)'].mean()
drug_mean
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.368318
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
drug_median = ram_groupby['Tumor Volume (mm3)'].median()
drug_median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.909965
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
drug_var = ram_groupby['Tumor Volume (mm3)'].var()
drug_var
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     42.278090
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
drug_std = ram_groupby['Tumor Volume (mm3)'].std()
drug_std
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.502160
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
drug_sem = ram_groupby['Tumor Volume (mm3)'].sem()
drug_sem
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.514041
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
#summary_table 
summary = {'Mean Tumor Volume':drug_mean,
          'Median Tumor Volume':drug_median,
          'Varience Tumor Volume':drug_var,
          'Standard Deviation Tumor Volume':drug_std,
          'Standard Error Mean Tumor Volume':drug_sem}
summary_df = pd.DataFrame(data=summary)
summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Varience Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.368318            50.909965              42.278090
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Standard Deviation Tumor Volume  \
# Drug Regimen
# Capomulin                            4.994774
# Ceftamin                             6.268188
# Infubinol                            6.567243
# Ketapril                             8.279709
# Naftisol                             8.134708
# Placebo                              7.821003
# Propriva                             6.502160
# Ramicane                             4.846308
# Stelasyn                             7.710419
# Zoniferol                            6.966589
#
#               Standard Error Mean Tumor Volume
# Drug Regimen
# Capomulin                             0.329346
# Ceftamin                              0.469821
# Infubinol                             0.492236
# Ketapril                              0.603860
# Naftisol                              0.596466
# Placebo                               0.581331
# Propriva                              0.514041
# Ramicane                              0.320955
# Stelasyn                              0.573111
# Zoniferol                             0.516398

# %%
#bar plot showing total number of unique mice test on each drug regimen using pandas
mice_drug_count = mouse_drop.groupby(['Drug Regimen']).count()['Mouse ID']
mice_drug_count
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     160
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# Name: Mouse ID, dtype: int64

# %%
mice_drug_count.plot.bar(color='red')
plt.title('Mice on Different Drug Regimens PANDAS')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice')
plt.show()

# %%
#total number of unique mice tested on each drug using pyplot
mice_list = mice_drug_count.tolist()
mice_list
drug_list = ['Capomulin', 'Ceftamin','Infubinol','Ketapril','Naftisol'
            'Placebo','Propriva','Ramicane','Stelasyn','Zoniferol']

# %%
x_axis = np.arange(0, len(mice_list))
tick_loc
for x in x_axis:
    tick_loc.append(x)
plt.xticks(tick_loc, drug_list)
plt.title('Mice on Different Drug Regimens Pyplot')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice')
plt.bar(x_axis, mice_list, facecolor='red')
plt.show()

# %%
#pie plot distribution female v male 
mice_sex = mouse_data.groupby('Sex')
mice_sex.count()
mice_sex = mice_sex[['Mouse ID']]
mice_sex.count()
# Out:
#         Mouse ID
# Sex
# Female       124
# Male         125

# %%
mice_sex.plot.pie(y='Mouse ID')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(self)
#     330             def f(self):
# --> 331                 return getattr(self.plot, name)(*args, **kwargs)
#     332
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_core.py in pie(self, **kwargs)
#    1417             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1418         return self(kind="pie", **kwargs)
#    1419
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, kind, **kwargs)
#    1461         data = data.fillna(value=0)
# -> 1462         if (data < 0).any().any():
#    1463             raise ValueError(f"{kind} doesn't allow negative values")
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63
# ---> 64         return method(self, other)
#      65
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      56     else:
# ---> 57         result = libops.scalar_compare(x.ravel(), y, op)
#      58     return result.reshape(x.shape)
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-3b5b4d280a7b> in <module>
# ----> 1 mice_sex.plot.pie(y='Mouse ID')
#       2 plt.show()
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in attr(*args, **kwargs)
#     331                 return getattr(self.plot, name)(*args, **kwargs)
#     332
# --> 333             return self._groupby.apply(f)
#     334
#     335         return attr
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     744
#     745                 with _group_selection_context(self):
# --> 746                     return self._python_apply_general(f)
#     747
#     748         return result
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     749
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#     753         return self._wrap_applied_output(
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     204             # group might be modified
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#     208                 mutated = True
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(self)
#     329         def attr(*args, **kwargs):
#     330             def f(self):
# --> 331                 return getattr(self.plot, name)(*args, **kwargs)
#     332
#     333             return self._groupby.apply(f)
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_core.py in pie(self, **kwargs)
#    1416         ):
#    1417             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1418         return self(kind="pie", **kwargs)
#    1419
#    1420     def scatter(self, x, y, s=None, c=None, **kwargs):
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
#      62     plot_obj.draw()
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, kind, **kwargs)
#    1460     def __init__(self, data, kind=None, **kwargs):
#    1461         data = data.fillna(value=0)
# -> 1462         if (data < 0).any().any():
#    1463             raise ValueError(f"{kind} doesn't allow negative values")
#    1464         MPLPlot.__init__(self, data, kind=kind, **kwargs)
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#     249     else:
#
# ~/opt/anaconda3/envs/PythonDataUPenn/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      55         result = libops.vec_compare(x.ravel(), y, op)
#      56     else:
# ---> 57         result = libops.scalar_compare(x.ravel(), y, op)
#      58     return result.reshape(x.shape)
#      59
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
